# %%
  # !pip install koreanize-matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 19.6 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import koreanize_matplotlib
from matplotlib import rc
from sklearn.preprocessing import StandardScaler
import matplotlib.font_manager as fm
from sklearn.cluster import KMeans
import seaborn as sns
from sklearn.decomposition import PCA
# %matplotlib inline

# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as stats

# 데이터 로드

data = pd.read_excel('달서구 MCLP 데이터프레임.xlsx')

# 히스토그램과 Q-Q 플롯을 위한 열 목록
columns_to_check = ['수요 지수', '인프라 지수', '접근성 지수', '환경 지수']

# 데이터 시각화: 히스토그램 및 Q-Q 플롯
plt.figure(figsize=(12, len(columns_to_check) * 4))

for i, column in enumerate(columns_to_check):
    plt.subplot(len(columns_to_check), 2, 2*i + 1)
    plt.hist(data[column], bins=20, density=True, alpha=0.6, color='g')
    plt.title(f'{column} 히스토그램')

    plt.subplot(len(columns_to_check), 2, 2*i + 2)
    stats.probplot(data[column], dist="norm", plot=plt)
    plt.title(f'{column} Q-Q Plot')

plt.tight_layout()
plt.show()

# 정규성 검정 (Shapiro-Wilk 테스트) 수행
normality_test_results = {}

for column in columns_to_check:
    stat, p_value = stats.shapiro(data[column])
    normality_test_results[column] = {'Statistic': stat, 'p-value': p_value}

normality_test_results
# Out:
# {'수요 지수': {'Statistic': 0.8947373252121587, 'p-value': 0.06623065669863888},
#  '인프라 지수': {'Statistic': 0.9401833990185362, 'p-value': 0.3512662887711816},
#  '접근성 지수': {'Statistic': 0.933618426836586, 'p-value': 0.27801737970741236},
#  '환경 지수': {'Statistic': 0.9382069174446304, 'p-value': 0.3276280312087309}}

# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as stats

# 데이터 로드

data = pd.read_excel('북구 MCLP 데이터프레임.xlsx')

# 히스토그램과 Q-Q 플롯을 위한 열 목록
columns_to_check = ['수요 지수', '인프라 지수', '접근성 지수', '환경 지수']

# 데이터 시각화: 히스토그램 및 Q-Q 플롯
plt.figure(figsize=(12, len(columns_to_check) * 4))

for i, column in enumerate(columns_to_check):
    plt.subplot(len(columns_to_check), 2, 2*i + 1)
    plt.hist(data[column], bins=20, density=True, alpha=0.6, color='g')
    plt.title(f'{column} 히스토그램')

    plt.subplot(len(columns_to_check), 2, 2*i + 2)
    stats.probplot(data[column], dist="norm", plot=plt)
    plt.title(f'{column} Q-Q Plot')

plt.tight_layout()
plt.show()

# 정규성 검정 (Shapiro-Wilk 테스트) 수행
normality_test_results = {}

for column in columns_to_check:
    stat, p_value = stats.shapiro(data[column])
    normality_test_results[column] = {'Statistic': stat, 'p-value': p_value}

normality_test_results
# Out:
# {'수요 지수': {'Statistic': 0.952044256287805, 'p-value': 0.5227511254645472},
#  '인프라 지수': {'Statistic': 0.9633884194555683, 'p-value': 0.7234655498116769},
#  '접근성 지수': {'Statistic': 0.9230680628796805, 'p-value': 0.18896633556117776},
#  '환경 지수': {'Statistic': 0.8751164414333423, 'p-value': 0.032594730481448744}}

# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as stats

# 데이터 로드

data = pd.read_excel('대구 클러스터링 표준화 전.xlsx')

# 히스토그램과 Q-Q 플롯을 위한 열 목록
columns_to_check = ['전체 노인인구 ', '독거노인 ', '병원 수', '약국 수','경로당 수','공공체육시설 수','음식점 수','버스정류장 수','지하철 역 수','공원 수']

# 데이터 시각화: 히스토그램 및 Q-Q 플롯
plt.figure(figsize=(12, len(columns_to_check) * 4))

for i, column in enumerate(columns_to_check):
    plt.subplot(len(columns_to_check), 2, 2*i + 1)
    plt.hist(data[column], bins=20, density=True, alpha=0.6, color='g')
    plt.title(f'{column} 히스토그램')

    plt.subplot(len(columns_to_check), 2, 2*i + 2)
    stats.probplot(data[column], dist="norm", plot=plt)
    plt.title(f'{column} Q-Q Plot')

plt.tight_layout()
plt.show()

# 정규성 검정 (Shapiro-Wilk 테스트) 수행
normality_test_results = {}

for column in columns_to_check:
    stat, p_value = stats.shapiro(data[column])
    normality_test_results[column] = {'Statistic': stat, 'p-value': p_value}

normality_test_results
# Out:
# {'전체 노인인구 ': {'Statistic': 0.955006775411157, 'p-value': 0.7614222555503329},
#  '독거노인 ': {'Statistic': 0.9819101600942736, 'p-value': 0.9717326036091383},
#  '병원 수': {'Statistic': 0.8666634047117237, 'p-value': 0.13978535625971217},
#  '약국 수': {'Statistic': 0.9351916963571278, 'p-value': 0.5644753365840285},
#  '경로당 수': {'Statistic': 0.8627901556043938, 'p-value': 0.12799445889192884},
#  '공공체육시설 수': {'Statistic': 0.9587467491056855, 'p-value': 0.7980801297780324},
#  '음식점 수': {'Statistic': 0.9287399670508463, 'p-value': 0.5046780741875259},
#  '버스정류장 수': {'Statistic': 0.8767520763688809, 'p-value': 0.17528532885895626},
#  '지하철 역 수': {'Statistic': 0.9568693268211743, 'p-value': 0.7798065593485537},
#  '공원 수': {'Statistic': 0.9172147244023138, 'p-value': 0.40767338058397984}}
