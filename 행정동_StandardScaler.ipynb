# %%
  # !pip install koreanize-matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 30.5 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import koreanize_matplotlib
from matplotlib import rc
from sklearn.preprocessing import StandardScaler
import matplotlib.font_manager as fm
from sklearn.cluster import KMeans
import seaborn as sns
from sklearn.decomposition import PCA
# %matplotlib inline

# %%
df = pd.read_excel('북구 MCLP 데이터프레임.xlsx')
df.head()
# Out:
#   행정구역         위도          경도     수요 지수      인프라 지수     접근성 지수     환경 지수
# 0  고성동  35.881913  128.583580  0.299125   69.137360  38.568621  4.170558
# 1  칠성동  35.879109  128.599926  0.283714   76.387249  56.315600  4.928135
# 2  침산동  35.890332  128.581175  0.285956   68.776651  27.454857  5.424109
# 3  산격동  35.900382  128.596973  0.418416   68.878806  30.028195  4.029145
# 4  대현동  35.882169  128.605823  0.378396  102.608847  21.903962  3.678443

# %%
columns_to_drop = ['행정구역', '위도', '경도']

# 열을 제거한 새로운 데이터프레임 생성
dfstandard = df.drop(columns=columns_to_drop)

# 결과 확인
dfstandard.head()
# Out:
#       수요 지수      인프라 지수     접근성 지수     환경 지수
# 0  0.299125   69.137360  38.568621  4.170558
# 1  0.283714   76.387249  56.315600  4.928135
# 2  0.285956   68.776651  27.454857  5.424109
# 3  0.418416   68.878806  30.028195  4.029145
# 4  0.378396  102.608847  21.903962  3.678443

# %%
# 숫자 데이터만 선택
df_numeric = dfstandard.select_dtypes(include='number')

# StandardScaler를 사용하여 숫자 데이터만 표준화
scaler = StandardScaler()
df_standardized_values = scaler.fit_transform(df_numeric)

# 표준화된 값을 가지고 새로운 데이터프레임 생성
df_standardized = pd.DataFrame(df_standardized_values, columns=df_numeric.columns)

# 결과 표시
df_standardized.head()
# Out:
#       수요 지수    인프라 지수    접근성 지수     환경 지수
# 0 -0.041846 -0.329415  0.162206 -0.815555
# 1 -0.241005 -0.131716  1.713763 -0.741200
# 2 -0.212040 -0.339251 -0.809432 -0.692521
# 3  1.499799 -0.336465 -0.584454 -0.829435
# 4  0.982603  0.583326 -1.294727 -0.863856

# %%
df_standardized['행정구역'] = df['행정구역']
df_standardized['위도'] = df['위도']
df_standardized['경도'] = df['경도']
df_standardized.to_excel('df_standardized_북구.xlsx', index=False)
df_standardized = df_standardized[['행정구역', '위도', '경도', '수요 지수', '인프라 지수', '접근성 지수', '환경 지수']]
df_standardized.head()
# Out:
#   행정구역         위도          경도     수요 지수    인프라 지수    접근성 지수     환경 지수
# 0  고성동  35.881913  128.583580 -0.041846 -0.329415  0.162206 -0.815555
# 1  칠성동  35.879109  128.599926 -0.241005 -0.131716  1.713763 -0.741200
# 2  침산동  35.890332  128.581175 -0.212040 -0.339251 -0.809432 -0.692521
# 3  산격동  35.900382  128.596973  1.499799 -0.336465 -0.584454 -0.829435
# 4  대현동  35.882169  128.605823  0.982603  0.583326 -1.294727 -0.863856

# %%
df = pd.read_excel('달서구 MCLP 데이터프레임.xlsx')
df.head()
# Out:
#   행정구역         위도          경도     수요 지수      인프라 지수     접근성 지수      환경 지수
# 0  성당동  35.840586  128.553099  0.304071   81.016770  38.631993   5.302272
# 1  두류동  35.857762  128.567286  0.460420   33.413898  20.238537   2.304928
# 2  본리동  35.840994  128.543159  0.206751  115.957199  50.875622  14.092505
# 3  감삼동  35.851547  128.550282  0.218408  131.040335  24.797407  11.598384
# 4  죽전동  35.857790  128.539013  0.261907   19.982135   8.775946   9.128660

# %%
columns_to_drop = ['행정구역', '위도', '경도']

# 열을 제거한 새로운 데이터프레임 생성
dfstandard = df.drop(columns=columns_to_drop)

# 결과 확인
dfstandard.head()
# Out:
#       수요 지수      인프라 지수     접근성 지수      환경 지수
# 0  0.304071   81.016770  38.631993   5.302272
# 1  0.460420   33.413898  20.238537   2.304928
# 2  0.206751  115.957199  50.875622  14.092505
# 3  0.218408  131.040335  24.797407  11.598384
# 4  0.261907   19.982135   8.775946   9.128660

# %%
# 숫자 데이터만 선택
df_numeric = dfstandard.select_dtypes(include='number')

# StandardScaler를 사용하여 숫자 데이터만 표준화
scaler = StandardScaler()
df_standardized_values = scaler.fit_transform(df_numeric)

# 표준화된 값을 가지고 새로운 데이터프레임 생성
df_standardized = pd.DataFrame(df_standardized_values, columns=df_numeric.columns)

# 결과 표시
df_standardized.head()
# Out:
#       수요 지수    인프라 지수    접근성 지수     환경 지수
# 0 -0.213645 -0.274135  0.194885 -1.230006
# 1  0.866784 -1.169550 -1.351751 -1.647315
# 2 -0.886153  0.383099  1.224405 -0.006174
# 3 -0.805602  0.666814 -0.968413 -0.353422
# 4 -0.505012 -1.422203 -2.315596 -0.697272

# %%
df_standardized['행정구역'] = df['행정구역']
df_standardized['위도'] = df['위도']
df_standardized['경도'] = df['경도']
df_standardized.to_excel('df_standardized_달서구.xlsx', index=False)
df_standardized = df_standardized[['행정구역', '위도', '경도', '수요 지수', '인프라 지수', '접근성 지수', '환경 지수']]
df_standardized.head()
# Out:
#   행정구역         위도          경도     수요 지수    인프라 지수    접근성 지수     환경 지수
# 0  성당동  35.840586  128.553099 -0.213645 -0.274135  0.194885 -1.230006
# 1  두류동  35.857762  128.567286  0.866784 -1.169550 -1.351751 -1.647315
# 2  본리동  35.840994  128.543159 -0.886153  0.383099  1.224405 -0.006174
# 3  감삼동  35.851547  128.550282 -0.805602  0.666814 -0.968413 -0.353422
# 4  죽전동  35.857790  128.539013 -0.505012 -1.422203 -2.315596 -0.697272
